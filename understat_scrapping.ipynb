# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
#scrape a single game shots. We will allow users to enter a base url
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match

#Use requests to get the webpage and BeautifulSoup to parse the page
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')
# Out:
# Please enter the match id: 460

# %%
#get only the shotsData
strings = scripts[1].string
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x2252050\\x22,\\x22minute\\x22\\x3A\\x2211\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.8530000305175781\\x22,\\x22Y\\x22\\x3A\\x220.7269999694824218\\x22,\\x22xG\\x22\\x3A\\x220.03313170000910759\\x22,\\x22player\\x22\\x3A\\x22Anthony\\x20Martial\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22553\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222015\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x22460\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Bournemouth\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222016\\x2D05\\x2D17\\x2023\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Cameron\\x20Borthwick\\x2DJackson\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2252053\\x22,\\x22minute\\x22\\x3A\\x2242\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.9080000305175782\\x22,\\x22Y\\x22\\x3A\\x220.54\\x22,\\x22xG\\x22\\x3A\\x220.4620940089225769\\x22,\\x22player\\x22\\x3A\\x22Wayne\\x20Rooney\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22629\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222015\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x22460\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Bournemouth\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222016\\x2D05\\x2D17\\x2023\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Anthony\\x20Martial\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2252054\\x22,\\x22minute\\x22\\x3A\\x2245\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.785\\x22,\\x22Y\\x22\\x3A\\x220.475\\x22,\\x22xG\\x22\\x3A\\x220.039867300540208817\\x22,\\x22player\\x22\\x3A\\x22Wayne\\x20Rooney\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22629\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222015\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x22460\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Bournemouth\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222016\\x2D05\\x2D17\\x2023\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Jesse\\x20Lingard\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2252058\\x22,\\x22minute\\x22\\x3A\\x2253\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.715\\x22,\\x22Y\\x22\\x3A\\x220.48700000762939455\\x22,\\x22xG\\x22\\x3A\\x220.019785400480031967\\x22,\\x22player\\x22\\x3A\\x22Michael\\x20Carrick\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22654\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222015\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x22460\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Bournemouth\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222016\\x2D05\\x2D17\\x2023\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Cameron\\x20Borthwick\\x2DJackson\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x2252059\\x22,\\x22minute\\x22\\x3A\\x2258\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.89\\x22,\\x22Y\\x22\\x3A\\x220.43099998474121093\\x22,\\x22xG\\x22\\x3A\\x220.10920599848031998\\x22,\\x22player\\x22\\x3A\\x22Juan\\x20Mata\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22554\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222015\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x22460\ ...

# %%
# strip unnecessary symbols and get only JSON data
ind_start = strings.index("('")+2
ind_end = strings.index("')")
json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-22f5fe6acdc9> in <cell line: 2>()
#       1 # strip unnecessary symbols and get only JSON data
# ----> 2 ind_start = strings.index("('")+2
#       3 ind_end = strings.index("')")
#       4 json_data = strings[ind_start:ind_end]
#       5 json_data = json_data.encode('utf8').decode('unicode_escape')
#
# ValueError: substring not found

# %%
x = []
y = []
xG = []
result = []
team = []
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
col_names = ['x','y','xG','result','team']
df = pd.DataFrame([x,y,xG,result,team],index=col_names)
df = df.T
df
# Out:
#                       x                    y                    xG  \
# 0    0.8530000305175781   0.7269999694824218   0.03313170000910759
# 1    0.9080000305175782                 0.54    0.4620940089225769
# 2                 0.785                0.475  0.039867300540208817
# 3                 0.715  0.48700000762939455  0.019785400480031967
# 4                  0.89  0.43099998474121093   0.10920599848031998
# 5    0.8469999694824218                 0.53   0.09357749670743942
# 6                   0.7  0.38599998474121094   0.01414399966597557
# 7    0.9019999694824219  0.44799999237060545  0.017704999074339867
# 8    0.8490000152587891   0.5220000076293946   0.27525898814201355
# 9    0.8680000305175781   0.3390000152587891    0.0797405019402504
# 10   0.9059999847412109   0.4809999847412109    0.5453780293464661
# 11   0.7519999694824219   0.5929999923706055  0.031198300421237946
# 12  0.06800000190734863   0.5070000076293946                     0
# 13   0.8119999694824219                0.545   0.04222450032830238
# 14                 0.86   0.5779999923706055   0.08775229752063751
# 15   0.8419999694824218    0.539000015258789   0.11743400245904922
# 16   0.8569999694824219   0.3189999961853027   0.03908960148692131
# 17   0.8419999694824218   0.5479999923706055   0.07051140069961548
# 18    0.875999984741211   0.5420000076293945   0.06745319813489914
# 19                 0.91   0.5690000152587891   0.07900640368461609
#
#          result               team
# 0   MissedShots  Manchester United
# 1          Goal  Manchester United
# 2   BlockedShot  Manchester United
# 3   BlockedShot  Manchester United
# 4   BlockedShot  Manchester United
# 5   BlockedShot  Manchester United
# 6     SavedShot  Manchester United
# 7   MissedShots  Manchester United
# 8     SavedShot  Manchester United
# 9          Goal  Manchester United
# 10         Goal  Manchester United
# 11  MissedShots  Manchester United
# 12      OwnGoal  Manchester United
# 13  BlockedShot        Bournemouth
# 14  BlockedShot        Bournemouth
# 15  BlockedShot        Bournemouth
# 16  BlockedShot        Bournemouth
# 17  MissedShots        Bournemouth
# 18  MissedShots        Bournemouth
# 19  MissedShots        Bournemouth
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df, *['result'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df, *['team'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df, *['result', 'team'], **{})
# chart
